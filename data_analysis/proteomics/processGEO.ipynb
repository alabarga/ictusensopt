# %%
import os
import GEOparse
import pandas as pd
import numpy as np

# %% [markdown]
# ## GEOparse
#
# - https://geoparse.readthedocs.io/en/latest/Analyse_hsa-miR-124a-3p_transfection_time-course.html

# %%
geo_accession = 'GSE162955'

# %%
# load/download GEO data
path = '/Users/alberto/TESIS/data'

# %%
gse = GEOparse.get_GEO(geo=geo_accession, destdir=path)
# Out:
# 20-Dec-2022 11:57:57 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE162nnn/GSE162955/soft/GSE162955_family.soft.gz to /Users/alberto/TESIS/data/GSE162955_family.soft.gz
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 18.0M/18.0M [00:06<00:00, 2.97MB/s]
# 20-Dec-2022 11:58:05 DEBUG downloader - Size validation passed
# 20-Dec-2022 11:58:05 DEBUG downloader - Moving /var/folders/tg/vg8p6d9n7fgg1cgqlm6s_csc0000gp/T/tmpgnd7hfen to /Users/alberto/TESIS/data/GSE162955_family.soft.gz
# 20-Dec-2022 11:58:05 DEBUG downloader - Successfully downloaded ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE162nnn/GSE162955/soft/GSE162955_family.soft.gz
# 20-Dec-2022 11:58:05 INFO GEOparse - Parsing /Users/alberto/TESIS/data/GSE162955_family.soft.gz:
# 20-Dec-2022 11:58:05 DEBUG GEOparse - DATABASE: GeoMiame
# 20-Dec-2022 11:58:05 DEBUG GEOparse - SERIES: GSE162955
# 20-Dec-2022 11:58:05 DEBUG GEOparse - PLATFORM: GPL17586
# ...

# %%
gse = GEOparse.get_GEO(filepath='/Users/alberto/TESIS/data/GSE162955_family.soft.gz')

# %%
gse.show_metadata()
# Out:
# !Series_title = Expression data from stroke patients brain samples
# !Series_geo_accession = GSE162955
# !Series_status = Public on Dec 31 2021
# !Series_submission_date = Dec 09 2020
# !Series_last_update_date = Jan 01 2022
# !Series_summary = Stroke is still a major cause of death and disability worldwide. A better comprehension of stroke pathophysiology is fundamental to reduce its dramatic outcome.
# !Series_summary = Our aim was to identify and verify gene expression changes that occur in the human brain after ischemia.
# ...

# %%
print('Type:\n', gse.metadata['type'])
print('Summary:\n', gse.metadata['summary'])
print('Overall Design:\n', gse.metadata['overall_design'])
# Out:
# Type:
#  ['Expression profiling by array']
# Summary:
#  ['Stroke is still a major cause of death and disability worldwide. A better comprehension of stroke pathophysiology is fundamental to reduce its dramatic outcome.', 'Our aim was to identify and verify gene expression changes that occur in the human brain after ischemia.']
# Overall Design:
# ...

# %%
gse.phenotype_data
# Out:
#                        title geo_accession                 status  \
# GSM4968878  16_contralateral    GSM4968878  Public on Dec 31 2021
# GSM4968879   16_infarct_core    GSM4968879  Public on Dec 31 2021
# GSM4968880  22_contralateral    GSM4968880  Public on Dec 31 2021
# GSM4968881   22_infarct_core    GSM4968881  Public on Dec 31 2021
# GSM4968882  32_contralateral    GSM4968882  Public on Dec 31 2021
# GSM4968883   32_infarct_core    GSM4968883  Public on Dec 31 2021
# GSM4968884  33_contralateral    GSM4968884  Public on Dec 31 2021
# GSM4968885   33_infarct_core    GSM4968885  Public on Dec 31 2021
# GSM4968886  35_contralateral    GSM4968886  Public on Dec 31 2021
# GSM4968887   35_infarct_core    GSM4968887  Public on Dec 31 2021
# GSM4968888  36_contralateral    GSM4968888  Public on Dec 31 2021
# GSM4968889   36_infarct_core    GSM4968889  Public on Dec 31 2021
#
#            submission_date last_update_date type channel_count  \
# ...

# %%
gse.phenotype_data.iloc[0]
# Out:
# title                                                                   16_contralateral
# geo_accession                                                                 GSM4968878
# status                                                             Public on Dec 31 2021
# submission_date                                                              Dec 09 2020
# last_update_date                                                             Dec 31 2021
# type                                                                                 RNA
# channel_count                                                                          1
# source_name_ch1                                                         Brain homogenate
# organism_ch1                                                                Homo sapiens
# taxid_ch1                                                                           9606
# ...

# %%
gse.phenotype_data['characteristics_ch1.3.disease state']
# Out:
# GSM4968878    ischemic stroke
# GSM4968879    ischemic stroke
# GSM4968880    ischemic stroke
# GSM4968881    ischemic stroke
# GSM4968882    ischemic stroke
# GSM4968883    ischemic stroke
# GSM4968884    ischemic stroke
# GSM4968885    ischemic stroke
# GSM4968886    ischemic stroke
# GSM4968887    ischemic stroke
# GSM4968888    ischemic stroke
# GSM4968889    ischemic stroke
# Name: characteristics_ch1.3.disease state, dtype: object

# %%
gse.gpls
# Out:
# {'GPL17586': <d: GPL17586>}

# %%
dir(gse)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__metaclass__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_metadata_as_string',
#  '_get_object_as_soft',
#  '_phenotype_data',
#  'database',
#  'download_SRA',
#  'download_supplementary_files',
#  'geotype',
#  'get_accession',
#  'get_metadata_attribute',
#  'get_type',
#  'gpls',
#  'gsms',
#  'merge_and_average',
#  'metadata',
#  'name',
#  'phenotype_data',
#  'pivot_and_annotate',
#  'pivot_samples',
#  'relations',
#  'show_metadata',
#  'to_soft']

# %%
gse.gsms
# Out:
# {'GSM4968878': <SAMPLE: GSM4968878>,
#  'GSM4968879': <SAMPLE: GSM4968879>,
#  'GSM4968880': <SAMPLE: GSM4968880>,
#  'GSM4968881': <SAMPLE: GSM4968881>,
#  'GSM4968882': <SAMPLE: GSM4968882>,
#  'GSM4968883': <SAMPLE: GSM4968883>,
#  'GSM4968884': <SAMPLE: GSM4968884>,
#  'GSM4968885': <SAMPLE: GSM4968885>,
#  'GSM4968886': <SAMPLE: GSM4968886>,
#  'GSM4968887': <SAMPLE: GSM4968887>,
#  'GSM4968888': <SAMPLE: GSM4968888>,
#  'GSM4968889': <SAMPLE: GSM4968889>}

# %%
gse.gsms['GSM4968878'].table.head()
# Out:
#        ID_REF  VALUE
# 0  2824546_st  11.68
# 1  2824549_st  10.59
# 2  2824551_st  11.82
# 3  2824554_st  11.37
# 4  2827992_st  10.28

# %%
gse.gpls['GPL17586'].table.head()
# Out:
#                 ID      probeset_id seqname strand   start    stop  \
# 0  TC01000001.hg.1  TC01000001.hg.1    chr1      +   11869   14409
# 1  TC01000002.hg.1  TC01000002.hg.1    chr1      +   29554   31109
# 2  TC01000003.hg.1  TC01000003.hg.1    chr1      +   69091   70008
# 3  TC01000004.hg.1  TC01000004.hg.1    chr1      +  160446  161525
# 4  TC01000005.hg.1  TC01000005.hg.1    chr1      +  317811  328581
#
#    total_probes                                    gene_assignment  \
# 0            49  NR_046018 // DDX11L1 // DEAD/H (Asp-Glu-Ala-As...
# 1            60  ENST00000408384 // MIR1302-11 // microRNA 1302...
# 2            30  NM_001005484 // OR4F5 // olfactory receptor, f...
# 3            30  OTTHUMT00000007169 // OTTHUMG00000002525 // NU...
# 4           191  NR_028322 // LOC100132287 // uncharacterized L...
#
#                                      mrna_assignment  \
# 0  NR_046018 // RefSeq // Homo sapiens DEAD/H (As...
# ...

# %%
pivoted_control_samples = gse.pivot_samples('VALUE')

# %%
pivoted_control_samples.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'GSM4968878'}>,
#         <AxesSubplot: title={'center': 'GSM4968879'}>,
#         <AxesSubplot: title={'center': 'GSM4968880'}>],
#        [<AxesSubplot: title={'center': 'GSM4968881'}>,
#         <AxesSubplot: title={'center': 'GSM4968882'}>,
#         <AxesSubplot: title={'center': 'GSM4968883'}>],
#        [<AxesSubplot: title={'center': 'GSM4968884'}>,
#         <AxesSubplot: title={'center': 'GSM4968885'}>,
#         <AxesSubplot: title={'center': 'GSM4968886'}>],
#        [<AxesSubplot: title={'center': 'GSM4968887'}>,
#         <AxesSubplot: title={'center': 'GSM4968888'}>,
#         <AxesSubplot: title={'center': 'GSM4968889'}>]], dtype=object)

# %% [markdown]
# ## pyAffy
# - https://github.com/flo-compbio/pyaffy
# - https://github.com/flo-compbio/pyaffy-demos/blob/master/minimal/01%20-%20Downloading%20the%20data%20and%20running%20pyAffy.ipynb

# %%
 pip install qnorm

# %%
 pip install gseapy
